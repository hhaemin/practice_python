# %% [markdown]
# # 제로베이스 데이터 사이언스 스쿨 EDA Level Test 1
# ## 문제 소개
# - 총 3단계 데이터 분석 상황 제시
#     - 1, 2단계 60점
#     - 3단계 40점
#     - 총점 100점
# <br></br>
# - 1단계 DataFrame 불러오기 & 전처리
# - 2단계 원하는 정보 얻기
# - 3단계 시각화
# <br></br>
# ## 참고 사항
# - Check Functions 셀을 반드시 실행해주세요!
# - 여러분이 제출하신 답안을 채점하기 위한 코드입니다.
# - 각 문제마다 반드시, check_01_01(df) 함수를 실행해주시기를 바랍니다
# <br></br>
# - 1,2 단계는 채점 코드를 통해 채점합니다. 총 60점
# - 3단계는 채점자가 제출해주신 시각화 결과물을 직접 검토하여 채점합니다. 총 40점
# <br></br>
# - 파일 제목은 [DS]edatest_honggildong.ipynb 으로 제출해주시기 바랍니다.
#     - 성부터 소문자로 작성해주세요.
# - 제출은 제공드린 구글설문지를 통해 제출해주시면 감사하겠습니다.
# ---

# %% [markdown]
# # 1. Check Functions
# - grading 채점 코드 안에는 각 문제 번호에 따른 check_00_00() 라는 함수가 있습니다.
#
#     ```
#     from grading import check_01_01
#     from grading import check_01_02
#     from grading import check_01_03
#     from grading import check_02_01
#     from grading import check_02_02
#     from grading import check_02_03
#     from grading import check_02_04
#     from grading import check_02_05
#     ```
#
# - 답안을 작성하신 후에 반드시 채점 코드까지 결과값까지 포함하여 제출해주시기를 바랍니다.
#
# ex)
# check_01_01(df)
#
# 정답입니다! 10점 누적 되었습니다!
#
# 현재 누적 점수: 10 / 100

# %%
# 채점을 위한 코드입니다. 반드시 실행해주세요.
from grading import *

# %% [markdown]
# # 2. Download Target Data

# %% [markdown]
# ##### Data 출처
# - Source: [서울시 열린데이터](https://data.seoul.go.kr/dataList/419/S/2/datasetView.do)
# - Data Download: [PinkWink Blog](https://pinkwink.kr/attachment/cfile1.uf@99740C3A5ECB0EA52889B3.txt)
#
# ##### 참고사항
# * 데이터에 콤마(,)가 많아 CSV로 변환이 곤란하여, 탭으로 구분하여 TXT로 제공합니다
# * 외국인 세대수 제외
# * 65세이상 고령자 수: 외국인 포함

# %%
# Load DataFrame
import pandas as pd

df_target = pd.read_csv('./datas/report.txt', sep='\t')
df_target.head()
# Out:
#          기간  자치구         세대          인구       인구.1       인구.2       인구.3  \
# 0        기간  자치구         세대          합계         합계         합계        한국인
# 1        기간  자치구         세대           계         남자         여자          계
# 2  2020.1/4   합계  4,354,006  10,013,781  4,874,995  5,138,786  9,733,655
# 3  2020.1/4  종로구     74,151     161,984     78,271     83,713    151,217
# 4  2020.1/4   중구     63,045     136,469     66,769     69,700    126,175
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,742,217  4,991,438  280,126  132,778  147,348   2.24  1,518,239
# 3     73,704     77,513   10,767    4,567    6,200   2.04     28,073
# 4     61,839     64,336   10,294    4,930    5,364      2     23,794

# %% [markdown]
# # 3. 문제

# %% [markdown]
# ## 1단계: DataFrame 불러오기 & 전처리
# ***

# %% [markdown]
# ### **문제 1-1)** 0, 1, 2번 index의 row를 제거하고 index를 초기화 하세요(기존 index는 삭제(drop)하세요).    (10점)
#
# - 예시: 0,1,2번 index 제거
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-001.png" style="margin:auto" width=130/>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=180 height=180/>
#
# - 예시: index 초기화
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-1-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-1-003.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_01 함수에 입력하여 채점하세요.

# %%
df = df_target.drop(index=[0,1,2])
df.head()
# Out:
#          기간  자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 3  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 4  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 5  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 6  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 7  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#       인구.5    인구.6   인구.7   인구.8 세대당인구 65세이상고령자
# 3   77,513  10,767  4,567  6,200  2.04   28,073
# 4   64,336  10,294  4,930  5,364     2   23,794
# 5  118,912  16,586  9,294  7,292  2.07   39,439
# 6  152,742   8,151  3,591  4,560   2.2   44,728
# 7  180,849  15,573  6,658  8,915  2.12   48,989

# %%
df = df.reset_index(drop=True)
df
# Out:
#           기간   자치구       세대       인구     인구.1     인구.2     인구.3     인구.4  \
# 0   2020.1/4   종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1   2020.1/4    중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2   2020.1/4   용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3   2020.1/4   성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4   2020.1/4   광진구  165,287  365,990  176,226  189,764  350,417  169,568
# 5   2020.1/4  동대문구  165,279  362,793  178,202  184,591  346,156  171,896
# 6   2020.1/4   중랑구  182,220  400,678  198,122  202,556  395,619  196,076
# 7   2020.1/4   성북구  193,801  454,532  218,561  235,971  442,494  213,926
# 8   2020.1/4   강북구  144,805  316,750  154,141  162,609  312,985  152,747
# 9   2020.1/4   도봉구  138,595  333,495  162,774  170,721  331,238  161,879
# 10  2020.1/4   노원구  217,148  535,495  258,696  276,799  531,037  256,726
# 11  2020.1/4   은평구  208,209  482,509  231,953  250,556  478,019  230,147
# 12  2020.1/4  서대문구  142,109  325,875  154,502  171,373  312,642  150,051
# 13  2020.1/4   마포구  176,133  386,086  181,204  204,882  374,570  176,943
# 14  2020.1/4   양천구  177,436  460,532  226,109  234,423  456,339  224,241
# 15  2020.1/4   강서구  263,645  595,703  288,134  307,569  589,302  285,085
# 16  2020.1/4   구로구  177,275  438,308  218,970  219,338  405,837  200,558
# 17  2020.1/4   금천구  111,542  251,370  128,643  122,727  232,583  118,044
# 18  2020.1/4  영등포구  177,743  404,766  202,617  202,149  371,903  184,316
# 19  2020.1/4   동작구  181,761  407,802  196,943  210,859  395,014  191,272
# 20  2020.1/4   관악구  270,760  516,662  258,982  257,680  499,374  250,743
# 21  2020.1/4   서초구  173,580  434,801  207,877  226,924  430,568  205,787
# 22  2020.1/4   강남구  233,624  549,898  263,163  286,735  544,804  260,654
# 23  2020.1/4   송파구  279,301  680,883  329,058  351,825  674,095  325,859
# 24  2020.1/4   강동구  190,019  457,042  225,226  231,816  452,646  223,189
#
#        인구.5    인구.6    인구.7    인구.8 세대당인구 65세이상고령자
# 0    77,513  10,767   4,567   6,200  2.04   28,073
# 1    64,336  10,294   4,930   5,364     2   23,794
# 2   118,912  16,586   9,294   7,292  2.07   39,439
# 3   152,742   8,151   3,591   4,560   2.2   44,728
# 4   180,849  15,573   6,658   8,915  2.12   48,989
# 5   174,260  16,637   6,306  10,331  2.09   60,367
# 6   199,543   5,059   2,046   3,013  2.17   66,764
# 7   228,568  12,038   4,635   7,403  2.28   72,172
# 8   160,238   3,765   1,394   2,371  2.16   61,660
# 9   169,359   2,257     895   1,362  2.39   60,023
# 10  274,311   4,458   1,970   2,488  2.45   82,682
# 11  247,872   4,490   1,806   2,684   2.3   82,245
# 12  162,591  13,233   4,451   8,782   2.2   53,038
# 13  197,627  11,516   4,261   7,255  2.13   53,283
# 14  232,098   4,193   1,868   2,325  2.57   62,761
# 15  304,217   6,401   3,049   3,352  2.24   85,992
# 16  205,279  32,471  18,412  14,059  2.29   67,432
# 17  114,539  18,787  10,599   8,188  2.09   38,508
# 18  187,587  32,863  18,301  14,562  2.09   59,373
# 19  203,742  12,788   5,671   7,117  2.17   63,378
# 20  248,631  17,288   8,239   9,049  1.84   76,664
# 21  224,781   4,233   2,090   2,143  2.48   58,332
# 22  284,150   5,094   2,509   2,585  2.33   72,602
# 23  348,236   6,788   3,199   3,589  2.41   89,539
# 24  229,457   4,396   2,037   2,359  2.38   66,401

# %%
check_01_01(df)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 10 / 60

# %% [markdown]
# ### **문제 1-2)** 현재의 컬럼명(current_columns)을 아래 new_columns와 같이 변경하세요.      (10점)
#
# - current_columns = ['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6', '인구.7', '인구.8', '세대당인구', '65세이상고령자']
# <br></br>
# - new_columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
# <br></br>
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_02 함수에 입력하여 채점하세요.

# %%
df.columns
# Out:
# Index(['기간', '자치구', '세대', '인구', '인구.1', '인구.2', '인구.3', '인구.4', '인구.5', '인구.6',
#        '인구.7', '인구.8', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
df.columns = ['기간', '자치구', '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '세대당인구', '65세이상고령자']
df.head()
# Out:
#          기간  자치구       세대       합계       남자       여자    한국인 계   한국인 남자  \
# 0  2020.1/4  종로구   74,151  161,984   78,271   83,713  151,217   73,704
# 1  2020.1/4   중구   63,045  136,469   66,769   69,700  126,175   61,839
# 2  2020.1/4  용산구  110,895  246,165  119,961  126,204  229,579  110,667
# 3  2020.1/4  성동구  135,643  307,193  149,891  157,302  299,042  146,300
# 4  2020.1/4  광진구  165,287  365,990  176,226  189,764  350,417  169,568
#
#     한국인 여자 등록외국인 계 등록외국인 남자 등록외국인 여자 세대당인구 65세이상고령자
# 0   77,513  10,767    4,567    6,200  2.04   28,073
# 1   64,336  10,294    4,930    5,364     2   23,794
# 2  118,912  16,586    9,294    7,292  2.07   39,439
# 3  152,742   8,151    3,591    4,560   2.2   44,728
# 4  180,849  15,573    6,658    8,915  2.12   48,989

# %%
check_01_02(df)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 20 / 60

# %% [markdown]
# ### **문제 1-3)** 천단위 구분자 " , "를 제거하고, data의 type을 int 또는 float으로 변경하세요.   (10점)
# - 기간, 자치구: 변경 없음
# <br></br>
# - '세대', '합계', '남자', '여자', '한국인 계', '한국인 남자', '한국인 여자', '등록외국인 계', '등록외국인 남자', '등록외국인 여자', '65세이상고령자': 천단위 구분자 "," 제거 및 int로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-002.png" style="margin:auto" width=150/>
# <br></br>
# - '세대당인구': float으로 타입 변경
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-1-3-003.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-1-3-004.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_01_03 함수에 입력하여 채점하세요.

# %%
df["세대당인구"] = df["세대당인구"].str.replace(",", "").astype(float)

df["합계"] = df["합계"].str.replace(",", "").astype(int)
df["세대"] = df["세대"].str.replace(",", "").astype(int)
df["남자"] = df["남자"].str.replace(",", "").astype(int)
df["여자"] = df["여자"].str.replace(",", "").astype(int)
df["한국인 계"] = df["한국인 계"].str.replace(",", "").astype(int)
df["한국인 남자"] = df["한국인 남자"].str.replace(",", "").astype(int)
df["한국인 여자"] = df["한국인 여자"].str.replace(",", "").astype(int)
df["등록외국인 계"] = df["등록외국인 계"].str.replace(",", "").astype(int)
df["등록외국인 남자"] = df["등록외국인 남자"].str.replace(",", "").astype(int)
df["등록외국인 여자"] = df["등록외국인 여자"].str.replace(",", "").astype(int)
df["65세이상고령자"] = df["65세이상고령자"].str.replace(",", "").astype(int)

df.head()
# Out:
#          기간  자치구      세대      합계      남자      여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구   74151  161984   78271   83713  151217   73704   77513
# 1  2020.1/4   중구   63045  136469   66769   69700  126175   61839   64336
# 2  2020.1/4  용산구  110895  246165  119961  126204  229579  110667  118912
# 3  2020.1/4  성동구  135643  307193  149891  157302  299042  146300  152742
# 4  2020.1/4  광진구  165287  365990  176226  189764  350417  169568  180849
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 0    10767      4567      6200   2.04     28073
# 1    10294      4930      5364   2.00     23794
# 2    16586      9294      7292   2.07     39439
# 3     8151      3591      4560   2.20     44728
# 4    15573      6658      8915   2.12     48989

# %%
check_01_03(df)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 30 / 60

# %% [markdown]
# ## 2단계: 원하는 정보 얻기

# %% [markdown]
# ### *Pandas DataFrame의 기능을 이용하여 아래 문제의 답을 구하세요.*
# ***
# #### 서울시는 아래와 같이 5개의 권역으로 구분됩니다.
# ![서울시 권역생활권](https://www.seoulsolution.kr/sites/default/files/images/%EC%B2%B4%EA%B3%846.jpg)
# - ref: [서울시-도시계획체계](https://www.seoulsolution.kr/ko/content/서울시-도시계획체계)
#
# - 도심권: ['종로구', '중구', '용산구']
# - 동북권: ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구']
# - 서북권: ['은평구', '서대문구', '마포구']
# - 서남권: ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구']
# - 동남권: ['서초구', '강남구', '송파구', '강동구']
# ***

# %%
region_dict = {'도심권': ['종로구', '중구', '용산구'],
               '동북권': ['성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구'],
               '서북권': ['은평구', '서대문구', '마포구'],
               '서남권': ['양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구'],
               '동남권': ['서초구', '강남구', '송파구', '강동구']
               }

# %% [markdown]
# ### **문제 2-1)** 1단계에서 구한 DataFrame에 '권역' column을 추가하여 해당 구에 맞는 권역을 입력하세요.    (5점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-1-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-1-002.png" style="margin:auto" width=200/>
#
# - 완료 후 결과 dataframe 변수를 check_02_01 함수에 입력하여 채점하세요.

# %%
df.insert(2,'권역',region_dict)
df.head(2)
# Out:
#          기간  자치구   권역     세대      합계     남자     여자   한국인 계  한국인 남자  한국인 여자  \
# 0  2020.1/4  종로구  NaN  74151  161984  78271  83713  151217   73704   77513
# 1  2020.1/4   중구  NaN  63045  136469  66769  69700  126175   61839   64336
#
#    등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 0    10767      4567      6200   2.04     28073
# 1    10294      4930      5364   2.00     23794

# %%
df['권역'] = ['도심권','도심권','도심권','동북권','동북권','동북권','동북권','동북권','동북권','동북권','동북권',
            '서북권','서북권','서북권','서남권','서남권','서남권','서남권','서남권','서남권','서남권',
            '동남권','동남권','동남권','동남권']
df
# Out:
#           기간   자치구   권역      세대      합계      남자      여자   한국인 계  한국인 남자  \
# 0   2020.1/4   종로구  도심권   74151  161984   78271   83713  151217   73704
# 1   2020.1/4    중구  도심권   63045  136469   66769   69700  126175   61839
# 2   2020.1/4   용산구  도심권  110895  246165  119961  126204  229579  110667
# 3   2020.1/4   성동구  동북권  135643  307193  149891  157302  299042  146300
# 4   2020.1/4   광진구  동북권  165287  365990  176226  189764  350417  169568
# 5   2020.1/4  동대문구  동북권  165279  362793  178202  184591  346156  171896
# 6   2020.1/4   중랑구  동북권  182220  400678  198122  202556  395619  196076
# 7   2020.1/4   성북구  동북권  193801  454532  218561  235971  442494  213926
# 8   2020.1/4   강북구  동북권  144805  316750  154141  162609  312985  152747
# 9   2020.1/4   도봉구  동북권  138595  333495  162774  170721  331238  161879
# 10  2020.1/4   노원구  동북권  217148  535495  258696  276799  531037  256726
# 11  2020.1/4   은평구  서북권  208209  482509  231953  250556  478019  230147
# 12  2020.1/4  서대문구  서북권  142109  325875  154502  171373  312642  150051
# 13  2020.1/4   마포구  서북권  176133  386086  181204  204882  374570  176943
# 14  2020.1/4   양천구  서남권  177436  460532  226109  234423  456339  224241
# 15  2020.1/4   강서구  서남권  263645  595703  288134  307569  589302  285085
# 16  2020.1/4   구로구  서남권  177275  438308  218970  219338  405837  200558
# 17  2020.1/4   금천구  서남권  111542  251370  128643  122727  232583  118044
# 18  2020.1/4  영등포구  서남권  177743  404766  202617  202149  371903  184316
# 19  2020.1/4   동작구  서남권  181761  407802  196943  210859  395014  191272
# 20  2020.1/4   관악구  서남권  270760  516662  258982  257680  499374  250743
# 21  2020.1/4   서초구  동남권  173580  434801  207877  226924  430568  205787
# 22  2020.1/4   강남구  동남권  233624  549898  263163  286735  544804  260654
# 23  2020.1/4   송파구  동남권  279301  680883  329058  351825  674095  325859
# 24  2020.1/4   강동구  동남권  190019  457042  225226  231816  452646  223189
#
#     한국인 여자  등록외국인 계  등록외국인 남자  등록외국인 여자  세대당인구  65세이상고령자
# 0    77513    10767      4567      6200   2.04     28073
# 1    64336    10294      4930      5364   2.00     23794
# 2   118912    16586      9294      7292   2.07     39439
# 3   152742     8151      3591      4560   2.20     44728
# 4   180849    15573      6658      8915   2.12     48989
# 5   174260    16637      6306     10331   2.09     60367
# 6   199543     5059      2046      3013   2.17     66764
# 7   228568    12038      4635      7403   2.28     72172
# 8   160238     3765      1394      2371   2.16     61660
# 9   169359     2257       895      1362   2.39     60023
# 10  274311     4458      1970      2488   2.45     82682
# 11  247872     4490      1806      2684   2.30     82245
# 12  162591    13233      4451      8782   2.20     53038
# 13  197627    11516      4261      7255   2.13     53283
# 14  232098     4193      1868      2325   2.57     62761
# 15  304217     6401      3049      3352   2.24     85992
# 16  205279    32471     18412     14059   2.29     67432
# 17  114539    18787     10599      8188   2.09     38508
# 18  187587    32863     18301     14562   2.09     59373
# 19  203742    12788      5671      7117   2.17     63378
# 20  248631    17288      8239      9049   1.84     76664
# 21  224781     4233      2090      2143   2.48     58332
# 22  284150     5094      2509      2585   2.33     72602
# 23  348236     6788      3199      3589   2.41     89539
# 24  229457     4396      2037      2359   2.38     66401

# %%
check_02_01(df)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 35 / 60

# %% [markdown]
# ### **문제 2-2)** 2-1에서 만든 DataFrame을 이용하여 Pandas의 pivot_table 메소드를 활용하여 각 권역별 아래 값의 합을 구하고, '합계'를 기준으로 내림차순 정렬하세요.      (5점)
#
# - 구할 값: ['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자']
#
# - 참고: [Pivot Table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# <br></br>
#     - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-001.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_02 함수에 입력하여 채점하세요.

# %%
df2 = df.pivot_table(index='권역',values=['합계', '세대', '여자', '한국인 계', '등록외국인 계', '65세이상고령자'],aggfunc=np.sum)
df2 = df2.sort_values(by='합계', ascending = False)
df2
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계
# 권역
# 동북권    497385    67938  1342778  1580313  3008988  3076926
# 서남권    454108   124791  1360162  1554745  2950352  3075143
# 동남권    286874    20511   876524  1097300  2102113  2122624
# 서북권    188566    29239   526451   626811  1165231  1194470
# 도심권     91306    37647   248091   279617   506971   544618

# %%
check_02_02(df2)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 40 / 60

# %% [markdown]
# ### **문제 2-3)** 2-2에서 만든 Pivot Table을 이용하여 각 권역별 ['고령자비율', '외국인비율', '여성비율', '세대당인구'] 컬럼을 만들어 아래와 같이 값을 입력하고 '외국인비율'을 기준으로 오름차순 정렬하세요.  (5점)
#
# - 고령자비율: 65세이상고령자 / 합계 * 100
#
# - 외국인비율: 등록외국인 계 / 합계 * 100
#
# - 여성비율: 여자 / 합계 * 100
#
# - 세대당인구: (합계 - 등록외국인 계) / 세대
# <br></br>
# - 예시: B/C 비율 및  B 기준 오름차순 정렬
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-2-2-002.png" style="margin:auto" width=150/>
#     <img src="./[문제보기용 이미지]images/01-2-3-001.png" style="margin:auto" width=230/>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_03 함수에 입력하여 채점하세요.

# %%
df2['고령자비율'] = df2['65세이상고령자'] / df2['합계'] * 100
df2['외국인비율'] = df2['등록외국인 계'] / df2['합계'] * 100
df2['여성비율'] = df2['여자'] / df2['합계'] * 100
df2['세대당인구'] = (df2['합계'] - df2['등록외국인 계'])/ df2['세대']
df2 = df2.sort_values(by='외국인비율', ascending = True)
df2
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
check_02_03(df2)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 45 / 60

# %% [markdown]
# ### **문제 2-4)** 2-1에서 만든 DataFrame을 이용하여 각 구별 ['고령자비율', '외국인비율', '여성비율'] 컬럼을 만들어 아래와 같이 값을 입력하고 '세대당인구'을 기준으로 내림차순 정렬하세요.  (5점)
# - 고령자비율: 65세이상고령자 / 합계 * 100
# - 외국인비율: 등록외국인 계 / 합계 * 100
# - 여성비율: 여자 / 합계 * 100
# - 완료 후 결과 dataframe 변수를 check_02_04 함수에 입력하여 채점하세요.

# %%
df3 = df

df3['고령자비율'] = df['65세이상고령자'] / df['합계'] * 100
df3['외국인비율'] = df['등록외국인 계'] / df['합계'] * 100
df3['여성비율'] = df['여자'] / df['합계'] * 100
df3['세대당인구'] = (df['합계'] - df['등록외국인 계'])/ df['세대']
df3 = df3.sort_values(['세대당인구'], ascending = False)

df3.head(3)
# Out:
#           기간  자치구   권역      세대      합계      남자      여자   한국인 계  한국인 남자  \
# 14  2020.1/4  양천구  서남권  177436  460532  226109  234423  456339  224241
# 21  2020.1/4  서초구  동남권  173580  434801  207877  226924  430568  205787
# 10  2020.1/4  노원구  동북권  217148  535495  258696  276799  531037  256726
#
#     한국인 여자  등록외국인 계  등록외국인 남자  등록외국인 여자     세대당인구  65세이상고령자      고령자비율  \
# 14  232098     4193      1868      2325  2.571851     62761  13.627935
# 21  224781     4233      2090      2143  2.480516     58332  13.415793
# 10  274311     4458      1970      2488  2.445507     82682  15.440294
#
#        외국인비율       여성비율
# 14  0.910469  50.902652
# 21  0.973549  52.190312
# 10  0.832501  51.690305

# %%
check_02_04(df3)
# Out:
# 정답입니다! 5점 누적 되었습니다!
# 현재 누적 점수: 50 / 60

# %% [markdown]
# ### **문제 2-5)** 2-3에서 만든 DataFrame을 이용하여 ['고령자비율', '외국인비율', '여성비율', '세대당인구']간의 피어슨 상관계수 행렬(Correlation matrix)를 구하세요. (10점)
#
# - 참고
#     - 상관계수(correlation coefficient): 두 변수가 함께 변하는 정도를 -1 ~ +1 범위의 수로 나타낸 것
#
#     - 피어슨 상관계수: 칼 피어슨(Karl Pearson)이 개발한 상관계수로, 일반적으로 상관계수라고 하면 피어슨 상관계수를 말함
#         - Standard Correlation Coefficient
#         - r(상관계수) = X와 Y가 함께 변하는 정도 / X와 Y가 각각 변하는 정도
# <br></br>
#     - 상관계수 행렬(Correlation Matrix): 변수간 상관계수를 보여주는 행렬
# <br></br>
#         - 예시: dog와 cat간의 상관계수 행렬
# <br></br>
#         <img src='./[문제보기용 이미지]images/01-2-5-001.png' width=150>
#         <img src='./[문제보기용 이미지]images/01-2-5-002.png' width=350>
# <br></br>
# - 완료 후 결과 dataframe 변수를 check_02_05 함수에 입력하여 채점하세요.

# %% [markdown]
# ## 3단계: 시각화

# %% [markdown]
# ### *Pandas DataFrame의 Plot기능, Matplotlib.pyplot, Seaborn 등 시각화 Library를 이용하여 문제와 같이 시각화하세요.*
# ***

# %%
# 한글 설정(Mac)
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False

f_path = '/Library/Fonts/Arial Unicode.ttf'
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# ### **문제 3-1)** 자치구별 고령자비율을 내림차순에 따라 barh 그래프로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-1-001.png" style="margin:auto" width=400/>

# %%
df3.head(3)
# Out:
#           기간  자치구   권역      세대      합계      남자      여자   한국인 계  한국인 남자  \
# 14  2020.1/4  양천구  서남권  177436  460532  226109  234423  456339  224241
# 21  2020.1/4  서초구  동남권  173580  434801  207877  226924  430568  205787
# 10  2020.1/4  노원구  동북권  217148  535495  258696  276799  531037  256726
#
#     한국인 여자  등록외국인 계  등록외국인 남자  등록외국인 여자     세대당인구  65세이상고령자      고령자비율  \
# 14  232098     4193      1868      2325  2.571851     62761  13.627935
# 21  224781     4233      2090      2143  2.480516     58332  13.415793
# 10  274311     4458      1970      2488  2.445507     82682  15.440294
#
#        외국인비율       여성비율
# 14  0.910469  50.902652
# 21  0.973549  52.190312
# 10  0.832501  51.690305

# %%
df4 = pd.pivot_table(
    df3,
    index="자치구",
    values=['고령자비율','외국인비율','여성비율','세대당인구']
)
df4.head(3)
# Out:
#          고령자비율     세대당인구       여성비율     외국인비율
# 자치구
# 강남구  13.202812  2.331969  52.143307  0.926354
# 강동구  14.528424  2.382109  50.720940  0.961837
# 강북구  19.466456  2.161424  51.336701  1.188635

# %%
def drawGraph():
    df4['고령자비율'].sort_values().plot(
        kind='barh',
        grid=True,
        title='고령자 비율',
        figsize=(8,8),
        legend='고령자비율')
    
drawGraph()

# %% [markdown]
# ### **문제 3-2)** 권역별 등록외국인 계를 PIE chart로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-2-001.png" style="margin:auto" width=400/>

# %%
df2
# Out:
#      65세이상고령자  등록외국인 계       세대       여자    한국인 계       합계      고령자비율  \
# 권역
# 동남권    286874    20511   876524  1097300  2102113  2122624  13.515064
# 동북권    497385    67938  1342778  1580313  3008988  3076926  16.164997
# 서북권    188566    29239   526451   626811  1165231  1194470  15.786583
# 서남권    454108   124791  1360162  1554745  2950352  3075143  14.767053
# 도심권     91306    37647   248091   279617   506971   544618  16.765145
#
#         외국인비율       여성비율     세대당인구
# 권역
# 동남권  0.966304  51.695449  2.398238
# 동북권  2.207983  51.360124  2.240868
# 서북권  2.447864  52.476077  2.213370
# 서남권  4.058055  50.558462  2.169118
# 도심권  6.912552  51.341858  2.043488

# %%
df5 = pd.pivot_table(
    df2,
    index="권역",
    values=['등록외국인 계']
)
df5.head(3)
# Out:
#      등록외국인 계
# 권역
# 도심권    37647
# 동남권    20511
# 동북권    67938

# %%
df5.values
# Out:
# array([[ 37647],
#        [ 20511],
#        [ 67938],
#        [124791],
#        [ 29239]])

# %%
df5.index
# Out:
# Index(['도심권', '동남권', '동북권', '서남권', '서북권'], dtype='object', name='권역')

# %%
import matplotlib.pyplot as plt

regist_for = [37647,20511,67938,124791,29239]
region = ['도심권', '동남권', '동북권', '서남권', '서북권']

plt.title('권역별 등록외국인 계')
plt.pie(regist_for,labels = region)
plt.legend(loc=1,bbox_to_anchor=(1.5, 0.2))
plt.show()

# %% [markdown]
# ### **문제 3-3)** 권역별 외국인비율을 Box plot으로 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-3-001.png" style="margin:auto" width=400/>

# %%
df6 = pd.pivot_table(
    df2,
    index="권역",
    values=['외국인비율']
)
df6
# Out:
#         외국인비율
# 권역
# 도심권  6.912552
# 동남권  0.966304
# 동북권  2.207983
# 서남권  4.058055
# 서북권  2.447864

# %%
df6.values
# Out:
# array([[6.91255155],
#        [0.96630397],
#        [2.2079829 ],
#        [4.05805519],
#        [2.44786391]])

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 도심권 to 서북권
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   외국인비율   5 non-null      float64
# dtypes: float64(1)
# memory usage: 80.0+ bytes

# %%
import pandas as pd
import numpy as np

# df6.boxplot(return_type='axes')
plt.rcParams["figure.figsize"] = (8, 3)
df6.boxplot(column=['외국인비율'],by=['권역'])
plt.title = '외국인비율'
plt.show()
# Out:
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49900 (\N{HANGUL SYLLABLE SIM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# df6.boxplot(x='권역', y='외국인비율', dodge=False)
# # x.get_legend().remove()
# plt.xlabel('권역', size=15)
# plt.ylabel('외국인비율',size=15)
# plt.ylim([0,10])
# plt.grid(True, alpha=0.3)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 df6.boxplot(x='권역', y='외국인비율', dodge=False)
#       5 # x.get_legend().remove()
#       6 plt.xlabel('권역', size=15)
#
# File ~/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/pandas/plotting/_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
#     525         layout=layout,
#     526         return_type=return_type,
#     527         **kwargs,
#     528     )
#
# File ~/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:458, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     443 def boxplot_frame(
#     444     self,
#     445     column=None,
#    (...)
#     454     **kwds,
#     455 ):
#     456     import matplotlib.pyplot as plt
# --> 458     ax = boxplot(
#     459         self,
#     460         column=column,
#     461         by=by,
#     462         ax=ax,
#     463         fontsize=fontsize,
#     464         grid=grid,
#     465         rot=rot,
#     466         figsize=figsize,
#     467         layout=layout,
#     468         return_type=return_type,
#     469         **kwds,
#     470     )
#     471     plt.draw_if_interactive()
#     472     return ax
#
# File ~/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:437, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     434     else:
#     435         data = data[columns]
# --> 437     result = plot_group(columns, data.values.T, ax, **kwds)
#     438     ax.grid(grid)
#     440 return result
#
# File ~/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py:367, in boxplot.<locals>.plot_group(keys, values, ax, **kwds)
#     365 keys = [pprint_thing(x) for x in keys]
#     366 values = [np.asarray(remove_na_arraylike(v), dtype=object) for v in values]
# --> 367 bp = ax.boxplot(values, **kwds)
#     368 if fontsize is not None:
#     369     ax.tick_params(axis="both", labelsize=fontsize)
#
# File ~/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# TypeError: boxplot() got multiple values for argument 'x'

# %% [markdown]
# ### **문제 3-4)** 자치구별 외국인비율-세대당인구를 Scatter plot에 나타내고, 상관관계에 따른 Regression Line을 시각화 하세요.    (10점)
#
# - 예시
# <br></br>
#     <img src="./[문제보기용 이미지]images/01-3-4-001.png" style="margin:auto" width=400/>

# %%
df4.head(1)
# Out:
#          고령자비율     세대당인구       여성비율     외국인비율
# 자치구
# 강남구  13.202812  2.331969  52.143307  0.926354

# %%
import seaborn as sns

def drawGraph2():
    sns.pairplot(
        data=df4, 
        x_vars=["세대당인구"],
        y_vars=["외국인비율"],
        kind="reg",
        height=4
    )
    plt.show()
drawGraph2()
# Out:
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/haemin/Downloads/yes/envs/ds_study/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
